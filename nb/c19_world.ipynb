# %% [markdown]
# ## Analysis of C19 world data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
import c19.data_functions_world as c19data
import c19.plotting as cplt
from c19.types import Country

# %% [markdown]
# ## Read in the data

# %%
df_world = c19data.get_data_world(update=True)
# Out:
# Reading latitude/longitude data from ../data/world_latlong.csv ...
# ...
# -- Done
# Obtaining climate data from 20191231 to 20200402 ...
# [1/204] Country Uruguay (UY) ...
# - Requesting data for (latitude,longitude) = (-32.522779,-55.765834999999996)
# [2/204] Country United_States_Virgin_Islands (VI) ...
# - Requesting data for (latitude,longitude) = (18.335765,-64.896335)
# [3/204] Country Bahrain (BH) ...
# - Requesting data for (latitude,longitude) = (25.930414,50.637772)
# [4/204] Country Eswatini (SZ) ...
# - Requesting data for (latitude,longitude) = (-26.522503,31.465866)
# -- Done
# Saving the final dataframe to ../data/data_world.csv ...
# -- Done

# %%
df_world
# Out:
#       dateRep  day  month  year  cases  deaths       countriesAndTerritories  \
# 0  2020-04-02    2      4  2020      0       1                       Uruguay
# 1  2020-04-01    1      4  2020     18       0                       Uruguay
# 2  2020-03-31   31      3  2020     11       0                       Uruguay
# 3  2020-03-30   30      3  2020      5       1                       Uruguay
# 4  2020-03-29   29      3  2020     66       0                       Uruguay
# 5  2020-03-28   28      3  2020      0       0                       Uruguay
# 6  2020-03-27   27      3  2020     21       0                       Uruguay
# 7  2020-03-26   26      3  2020     28       0                       Uruguay
# 8  2020-03-25   25      3  2020     27       0                       Uruguay
# 9  2020-03-24   24      3  2020      4       0                       Uruguay
# 10 2020-03-23   23      3  2020     23       0                       Uruguay
# ...

# %% [markdown]
# ## Notes
# Meteo data format:
# - `IR`: Downward Thermal Infrared (Longwave) Radiative Flux (kW-hr/m^2/day)
# - `sol`: All Sky Insolation Incident on a Horizontal Surface (kW-hr/m^2/day)
# - `prec`: Precipitation (mm/day)
# - `shum`: Specific Humidity at 2 Meters (kg kg-1)
# - `rhum`: Relative Humidity at 2 Meters (%)
# - `tmed`: Temperature at 2 Meters (C)
# - `tmax`: Maximum Temperature at 2 Meters (C)
# - `tmin`: Minimum Temperature at 2 Meters (C)
#
# **Note:** unavailable meteo values may be either NaN or -999

# %%
country = Country(name='Uruguay', code='AN')
country
# Out:
# Country(name='Uruguay', code='AN')

# %%
cplt.plot_cases_and_deaths(df_world[df_world.countriesAndTerritories == 'Uruguay'], country= country.name, figsize=(20,20), log=False)
# Out:
#  Total cases   confirmed =338
#  Total deaths  confirmed =2

# %% [markdown]
# ---
